# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
geopandas.read_file(geopandas.datasets.get_path(""))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-2a66e51dd0c8> in <module>
# ----> 1 geopandas.read_file(geopandas.datasets.get_path(""))
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\datasets\__init__.py in get_path(dataset)
#      28         msg = "The dataset '{data}' is not available. ".format(data=dataset)
#      29         msg += "Available datasets are {}".format(", ".join(available))
# ---> 30         raise ValueError(msg)
#
# ValueError: The dataset '' is not available. Available datasets are naturalearth_cities, naturalearth_lowres, nybb

# %%
# We restrict to South America.
ax = world[
    (world.continent == "Europe") & (~world.name.isin(["Russia", "France"]))
].plot(color="white", edgecolor="black", figsize=(15, 30))

plt.show()
