# %% [markdown]
# # Partnervertrag Analyse: Datenpräparation

# %%
# make imports from pa_lib possible (parent directory of file's directory)
import sys
from pathlib import Path

file_dir = Path.cwd()
parent_dir = file_dir.parent
sys.path.append(str(parent_dir))

# %%
# %load_ext autoreload
# %autoreload

import pandas as pd
import qgrid

from pa_lib.file  import store_bin, set_project_dir
from pa_lib.data  import desc_col, as_dtype, as_date, split_date_iso
from pa_lib.util  import obj_size
from pa_lib.types import dtFactor
from pa_lib.sql   import query
from pa_lib.ora   import Connection
from pa_lib.log   import info

# display long columns completely
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# ## Daten einlesen

# %%
pv_query = query('pv_2')

# %%
info('Starting PV query on APC Prod instance')
with Connection('APC_PROD_VDWH1') as c:
    pv_data_raw = c.long_query(pv_query)
info(f'Finished PV query, returned {obj_size(pv_data_raw)} of data: {pv_data_raw.shape}')
# Out:
# 2019-06-04 15:10:46 [INFO] Starting PV query on APC Prod instance
# 2019-06-04 15:11:57 [INFO] Finished query in 70.54s (17.87s CPU)
# 2019-06-04 15:12:01 [INFO] Finished PV query, returned 615.8 MB of data: (1693371, 11)

# %%
pv_data_raw.head()
# Out:
#     PV_NR  JAHR_KW  JAHR  KW    RES_BRUTTO  RES_NETTO_NETTO     AUS_BRUTTO  \
# 0  308945   201918  2019  18      0.000000         0.000000     228.846154
# 1   25191   201429  2014  29  33411.000000     20848.902661   53806.077599
# 2  307690   201436  2014  36  72466.000000     29455.679591  100834.058429
# 3  307690   201447  2014  47  37493.494733     20638.096253  116873.039189
# 4   27259   201547  2015  47   1430.000000       498.192745    4680.211563
#
#    AUS_NETTO_NETTO  \
# 0        42.185577
# 1     24592.008711
# 2     54515.924198
# 3     41887.827308
# 4      2972.215711
#
#                                                          PV_TITEL  PARTNER_NR  \
# 0                                 Surcuolm - Uhrentafeln [308945]      112060
# 1                              Interplakat Privatverträge [25191]      103707
# 2  Plakatierung_SBB/CFF/FFS: West Bahnhofmanagement (BM) [307690]      477164
# 3  Plakatierung_SBB/CFF/FFS: West Bahnhofmanagement (BM) [307690]      477164
# 4           KT Solothurn, Plakat-Standorte Kreisbauamt II [27259]      129877
#
#                                          PARTNER
# 0             Bergbahnen Piz Mundaun AG [112060]
# 1                        Interplakat AG [103707]
# 2       Schweizerische Bundesbahnen SBB [477164]
# 3       Schweizerische Bundesbahnen SBB [477164]
# 4  Baudepartement des Kantons Solothurn [129877]

# %%
desc_col(pv_data_raw, det=True)
# Out:
#                    DTYPE      NULLS  UNIQUE       MEM  \
# PV_NR              int64  0/1693371    7902   12.9 MB
# JAHR_KW            int64  0/1693371     418   12.9 MB
# JAHR              object  0/1693371       8   98.5 MB
# KW                object  0/1693371      53   95.3 MB
# RES_BRUTTO       float64  0/1693371   93446   12.9 MB
# RES_NETTO_NETTO  float64  0/1693371  242096   12.9 MB
# AUS_BRUTTO       float64  0/1693371  203380   12.9 MB
# AUS_NETTO_NETTO  float64  0/1693371  428799   12.9 MB
# PV_TITEL          object  0/1693371    7902  216.8 MB
# PARTNER_NR         int64  0/1693371    5793   12.9 MB
# PARTNER           object  0/1693371    5793  161.0 MB
#
#                                                                                  RANGE
# PV_NR                                                                      [26,311503]
# JAHR_KW                                                                [201401,202152]
# JAHR                                                                       [2014,2021]
# KW                                                                             [01,53]
# RES_BRUTTO                                                      [0.0,4089637.83883066]
# RES_NETTO_NETTO                                  [-25.599412008256,3221578.3203589036]
# AUS_BRUTTO                                                     [0.0,1577148.971208175]
# AUS_NETTO_NETTO                                [-13326.983333333334,940441.8088653579]
# PV_TITEL               [ Bern - Bethlehemstrasse 24 [26973],zb Zentralbahn AG [32060]]
# PARTNER_NR                                                             [100035,656032]
# PARTNER          ["Zürich" Versicherungs-Gesellschaft [495776],Özdemir Ökkes [614921]]

# %% [markdown]
# ## Leerwerte bereinigen, Datentypen korrigieren

# %%
pv_data_raw = pv_data_raw.dropna(how='any')

# %%
(obj_size(pv_data_raw), pv_data_raw.shape)
# Out:
# ('670.5 MB', (1682716, 11))

# %%
pv_data_raw = pv_data_raw.pipe(as_dtype, dtFactor, incl_dtype='object')

# %%
(obj_size(pv_data_raw), pv_data_raw.shape)
# Out:
# ('115.1 MB', (1693371, 11))

# %%
desc_col(pv_data_raw, det=True)
# Out:
#                     DTYPE      NULLS  UNIQUE      MEM  \
# PV_NR               int64  0/1693371    7902  25.8 MB
# JAHR_KW             int64  0/1693371     418  25.8 MB
# JAHR             category  0/1693371       8  14.5 MB
# KW               category  0/1693371      53  14.5 MB
# RES_BRUTTO        float64  0/1693371   93446  25.8 MB
# RES_NETTO_NETTO   float64  0/1693371  242096  25.8 MB
# AUS_BRUTTO        float64  0/1693371  203380  25.8 MB
# AUS_NETTO_NETTO   float64  0/1693371  428799  25.8 MB
# PV_TITEL         category  0/1693371    7902  17.5 MB
# PARTNER_NR          int64  0/1693371    5793  25.8 MB
# PARTNER          category  0/1693371    5793  16.8 MB
#
#                                                                                  RANGE
# PV_NR                                                                      [26,311503]
# JAHR_KW                                                                [201401,202152]
# JAHR                                                                       [2014,2021]
# KW                                                                             [01,53]
# RES_BRUTTO                                                      [0.0,4089637.83883066]
# RES_NETTO_NETTO                                  [-25.599412008256,3221578.3203589036]
# AUS_BRUTTO                                                     [0.0,1577148.971208175]
# AUS_NETTO_NETTO                                [-13326.983333333334,940441.8088653579]
# PV_TITEL               [ Bern - Bethlehemstrasse 24 [26973],zb Zentralbahn AG [32060]]
# PARTNER_NR                                                             [100035,656032]
# PARTNER          ["Zürich" Versicherungs-Gesellschaft [495776],Özdemir Ökkes [614921]]

# %%
pv_data_raw.head()
# Out:
#     PV_NR  JAHR_KW  JAHR  KW    RES_BRUTTO  RES_NETTO_NETTO     AUS_BRUTTO  \
# 0  308945   201918  2019  18      0.000000         0.000000     228.846154
# 1   25191   201429  2014  29  33411.000000     20848.902661   53806.077599
# 2  307690   201436  2014  36  72466.000000     29455.679591  100834.058429
# 3  307690   201447  2014  47  37493.494733     20638.096253  116873.039189
# 4   27259   201547  2015  47   1430.000000       498.192745    4680.211563
#
#    AUS_NETTO_NETTO  \
# 0        42.185577
# 1     24592.008711
# 2     54515.924198
# 3     41887.827308
# 4      2972.215711
#
#                                                          PV_TITEL  PARTNER_NR  \
# 0                                 Surcuolm - Uhrentafeln [308945]      112060
# 1                              Interplakat Privatverträge [25191]      103707
# 2  Plakatierung_SBB/CFF/FFS: West Bahnhofmanagement (BM) [307690]      477164
# 3  Plakatierung_SBB/CFF/FFS: West Bahnhofmanagement (BM) [307690]      477164
# 4           KT Solothurn, Plakat-Standorte Kreisbauamt II [27259]      129877
#
#                                          PARTNER
# 0             Bergbahnen Piz Mundaun AG [112060]
# 1                        Interplakat AG [103707]
# 2       Schweizerische Bundesbahnen SBB [477164]
# 3       Schweizerische Bundesbahnen SBB [477164]
# 4  Baudepartement des Kantons Solothurn [129877]

# %% [markdown]
# ## Netto = 0 ausfiltern, sortieren

# %%
pv_data = (pv_data_raw.query('AUS_NETTO_NETTO > 0')
           .sort_values(['JAHR_KW', 'PV_NR'])
           .reset_index(drop=True))

# %%
desc_col(pv_data, det=True)
# Out:
#                     DTYPE      NULLS  UNIQUE      MEM  \
# PV_NR               int64  0/1478359    7851  11.3 MB
# JAHR_KW             int64  0/1478359     418  11.3 MB
# JAHR             category  0/1478359       8   1.4 MB
# KW               category  0/1478359      53   1.4 MB
# RES_BRUTTO        float64  0/1478359   85293  11.3 MB
# RES_NETTO_NETTO   float64  0/1478359  215067  11.3 MB
# AUS_BRUTTO        float64  0/1478359  202953  11.3 MB
# AUS_NETTO_NETTO   float64  0/1478359  428790  11.3 MB
# PV_TITEL         category  0/1478359    7851   4.1 MB
# PARTNER_NR          int64  0/1478359    5767  11.3 MB
# PARTNER          category  0/1478359    5767   3.5 MB
#
#                                                                                  RANGE
# PV_NR                                                                      [26,311503]
# JAHR_KW                                                                [201401,202152]
# JAHR                                                                       [2014,2021]
# KW                                                                             [01,53]
# RES_BRUTTO                                                      [0.0,4089637.83883066]
# RES_NETTO_NETTO                                  [-25.599412008256,2566898.6604734533]
# AUS_BRUTTO                                          [0.692307692307,1577148.971208175]
# AUS_NETTO_NETTO                                     [0.409719602665,940441.8088653579]
# PV_TITEL               [ Bern - Bethlehemstrasse 24 [26973],zb Zentralbahn AG [32060]]
# PARTNER_NR                                                             [100035,656032]
# PARTNER          ["Zürich" Versicherungs-Gesellschaft [495776],Özdemir Ökkes [614921]]

# %% [markdown]
# ## Vertragsinformationen extrahieren

# %%
pv_idx = pv_data.groupby('PV_NR', as_index=True)

# %%
pv_info = pv_idx.agg({'PV_TITEL': 'first', 'RES_BRUTTO': 'sum', 'RES_NETTO_NETTO': 'sum', 'AUS_BRUTTO': 'sum', 'AUS_NETTO_NETTO': 'sum', 'PARTNER_NR': 'last', 'PARTNER': 'last',
                      'JAHR_KW': ['min', 'max']})
pv_info.columns = 'Titel totalResBrutto, totalResNettoNetto totalAusBrutto totalAusNettoNetto partnerNr Partner firstKw lastKw'.split()

# %%
desc_col(pv_info, det=True)
# Out:
#                        DTYPE   NULLS UNIQUE       MEM  \
# Titel                 object  0/7851   7851    1.1 MB
# totalResBrutto,      float64  0/7851   7658  122.7 KB
# totalResNettoNetto   float64  0/7851   7707  122.7 KB
# totalAusBrutto       float64  0/7851   7828  122.7 KB
# totalAusNettoNetto   float64  0/7851   7838  122.7 KB
# partnerNr              int64  0/7851   5767  122.7 KB
# Partner               object  0/7851   5767  823.9 KB
# firstKw                int64  0/7851    258  122.7 KB
# lastKw                 int64  0/7851    332  122.7 KB
# NettoNetto_Aus_2014  float64  0/7851   6650  122.7 KB
# NettoNetto_Aus_2015  float64  0/7851   6841  122.7 KB
# NettoNetto_Aus_2016  float64  0/7851   6972  122.7 KB
# NettoNetto_Aus_2017  float64  0/7851   7012  122.7 KB
# NettoNetto_Aus_2018  float64  0/7851   6944  122.7 KB
# NettoNetto_Aus_2019  float64  0/7851   6589  122.7 KB
# NettoNetto_Aus_2020  float64  0/7851    607  122.7 KB
# NettoNetto_Aus_2021  float64  0/7851     20  122.7 KB
# NettoNetto_Res_2014  float64  0/7851   6268  122.7 KB
# NettoNetto_Res_2015  float64  0/7851   6624  122.7 KB
# NettoNetto_Res_2016  float64  0/7851   6765  122.7 KB
# NettoNetto_Res_2017  float64  0/7851   6849  122.7 KB
# NettoNetto_Res_2018  float64  0/7851   6742  122.7 KB
# NettoNetto_Res_2019  float64  0/7851   6141  122.7 KB
# NettoNetto_Res_2020  float64  0/7851      1  122.7 KB
# NettoNetto_Res_2021  float64  0/7851      1  122.7 KB
#
#                                                                                      RANGE
# Titel                      [ Bern - Bethlehemstrasse 24 [26973],zb Zentralbahn AG [32060]]
# totalResBrutto,                                                   [0.0,200595358.35695997]
# totalResNettoNetto                                                 [0.0,128880929.3894724]
# totalAusBrutto                                        [22.739726027393,201559729.90018842]
# totalAusNettoNetto                                    [22.739726027393,129567091.89990559]
# partnerNr                                                                  [100035,656032]
# Partner              ["Zürich" Versicherungs-Gesellschaft [495776],Özdemir Ökkes [614921]]
# firstKw                                                                    [201401,201945]
# lastKw                                                                     [201401,202152]
# NettoNetto_Aus_2014                                               [0.0,15000520.852361444]
# NettoNetto_Aus_2015                                                [0.0,24479644.40972771]
# NettoNetto_Aus_2016                                                [0.0,25710155.96959826]
# NettoNetto_Aus_2017                                                [0.0,32350537.39230569]
# NettoNetto_Aus_2018                                               [0.0,31987249.049658258]
# NettoNetto_Aus_2019                                               [0.0,19838251.782577354]
# NettoNetto_Aus_2020                                                 [0.0,570198.364656595]
# NettoNetto_Aus_2021                                                [0.0,23179.93899243952]
# NettoNetto_Res_2014                                                [0.0,19569637.28949727]
# NettoNetto_Res_2015                                               [0.0,24543354.640506215]
# NettoNetto_Res_2016                                               [0.0,27810512.264195412]
# NettoNetto_Res_2017                                               [0.0,30583346.098969445]
# NettoNetto_Res_2018                                               [0.0,26374079.096303977]
# NettoNetto_Res_2019                                               [0.0,14576895.519999996]
# NettoNetto_Res_2020                                                              [0.0,0.0]
# NettoNetto_Res_2021                                                              [0.0,0.0]

# %%
qgrid.show_grid(pv_info.loc[:,'Titel NettoNetto_Aus_2017 NettoNetto_Aus_2018 NettoNetto_Aus_2019'.split()])
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# #### Jahres-Nettoumsätze

# %%
pvYearANetto = pv_data.groupby(['PV_NR', 'JAHR'], observed=True, as_index=False)[['AUS_NETTO_NETTO']].agg('sum')
pvYearRNetto = pv_data.groupby(['PV_NR', 'JAHR'], observed=True, as_index=False)[['RES_NETTO_NETTO']].agg('sum')
pvANetto = pvYearANetto.pivot(index='PV_NR', columns='JAHR', values='AUS_NETTO_NETTO').fillna(0).add_prefix('NettoNetto_Aus_')
pvRNetto = pvYearRNetto.pivot(index='PV_NR', columns='JAHR', values='RES_NETTO_NETTO').fillna(0).add_prefix('NettoNetto_Res_')

# %%
pv_info = pv_info.merge(pvANetto, on='PV_NR').merge(pvRNetto, on='PV_NR')

# %% [markdown]
# ## Daten speichern

# %%
set_project_dir('pv')

store_bin(pv_data, 'pv_data.feather')
store_bin(pv_info, 'pv_info.feather')
# Out:
# 2019-06-04 15:14:41 [INFO] Writing to file /home/pa/data/pv_data.feather
# 2019-06-04 15:14:41 [INFO] Written 88.0 MB
# 2019-06-04 15:14:41 [INFO] Finished storing binary file in 0.37s (1.62s CPU)
# 2019-06-04 15:14:41 [INFO] Writing to file /home/pa/data/pv_info.feather
# 2019-06-04 15:14:41 [INFO] Written 2.1 MB
# 2019-06-04 15:14:41 [INFO] Finished storing binary file in 0.02s (0.02s CPU)
